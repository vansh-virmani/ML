# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img=cv2.imread('hi.png')

# %%
img.shape
# Out:
# (1106, 826, 3)

# %%
plt.imshow(img)
plt.show()

# %%
rows,cols= img.shape[:2]

# %%
# translate image
#create trans;ation matrix
#format :

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df=pd.read_csv("data/Algerian_forest_fires_dataset_datanew.csv")
df_copy=df.copy()
df_copy.head()
df_copy.drop(["Unnamed: 0"],inplace=True,axis=1)
df_copy
df_copy.nunique()
df['Classes'].unique()
df_copy['Classes']=df_copy['Classes'].str.strip().str.lower()
df_copy['Classes'].unique()
df_copy
df_copy.drop(['day','month','year'],axis=1,inplace=True)
df_copy["Classes"] = df_copy["Classes"].map({"not fire": 0, "fire": 1})


df_copy['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
df_copy
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5        0
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4        0
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1        0
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0        0
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5        0
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...  ...      ...
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 238       1
# 239       1
# 240       1
# 241       1
# 242       1
#
# [243 rows x 12 columns]

# %%
##independent and Dependent Features
X = df_copy.drop(['FWI', 'Classes'], axis=1)
y=df_copy['FWI']

# %%
X.head()
y
# Out:
# 0      0.5
# 1      0.4
# 2      0.1
# 3      0.0
# 4      0.5
#       ...
# 238    6.5
# 239    0.0
# 240    0.2
# 241    0.7
# 242    0.5
# Name: FWI, Length: 243, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=42)

# %%
print(X_train.shape,y_train.shape,X_test.shape,y_test.shape)
# Out:
# (170, 10) (170,) (73, 10) (73,)

# %%
##feature Selection based on Correlation
X_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.640179 -0.295442 -0.303129  0.682819  0.495974
# RH             -0.640179  1.000000  0.201762  0.226259 -0.640759 -0.421517
# Ws             -0.295442  0.201762  1.000000  0.244784 -0.169620  0.009523
# Rain           -0.303129  0.226259  0.244784  1.000000 -0.536790 -0.288856
# FFMC            0.682819 -0.640759 -0.169620 -0.536790  1.000000  0.625593
# DMC             0.495974 -0.421517  0.009523 -0.288856  0.625593  1.000000
# DC              0.399434 -0.253547  0.092367 -0.304328  0.533040  0.870419
# ISI             0.608042 -0.715106 -0.004035 -0.341902  0.748574  0.692435
# BUI             0.474804 -0.373155  0.040699 -0.300998  0.613526  0.983426
# Region          0.238873 -0.394121 -0.182236 -0.051964  0.251710  0.210853
#
#                    DC       ISI       BUI    Region
# Temperature  0.399434  0.608042  0.474804  0.238873
# RH          -0.253547 -0.715106 -0.373155 -0.394121
# Ws           0.092367 -0.004035  0.040699 -0.182236
# Rain        -0.304328 -0.341902 -0.300998 -0.051964
# FFMC         0.533040  0.748574  0.613526  0.251710
# DMC          0.870419  0.692435  0.983426  0.210853
# DC           1.000000  0.524898  0.943125 -0.056844
# ISI          0.524898  1.000000  0.652179  0.290294
# BUI          0.943125  0.652179  1.000000  0.115434
# Region      -0.056844  0.290294  0.115434  1.000000

# %%
import seaborn as sns

# %% [markdown]
# ##Check for multicolliniearity- features must not be very high coreelated which leaks info to model

# %%
plt.figure(figsize=(12,10))
corr=X_train.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
def correlation(dataset, threshold):
    col_corr = set()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
#threshold-domain expertise
corr_features=correlation(X_train,0.85)

# %%
##drop the features
X_train.drop(corr_features,axis=1,inplace=True)
X_test.drop(corr_features,axis=1,inplace=True)

# %%
print("X_train_clf columns after dropping correlated features:")
display(X_train.columns)
# Out:
# X_train_clf columns after dropping correlated features:
# Index(['Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'ISI', 'Region'], dtype='object')

# %% [markdown]
# ##Features Scaling or Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %% [markdown]
# ##OUTLIER DETECTION

# %%
##Box plots
plt.subplots(figsize=(15, 5))
plt.subplot(1, 2, 1)
sns.boxplot(data=X_train)
plt.title('X_train Before Scaling')

plt.subplot(1, 2, 2)
sns.boxplot(data=X_train_scaled)
plt.title('X_train After Scaling')
# Out:
# Text(0.5, 1.0, 'X_train After Scaling')

# %%
#MOdel training- linear lasso ridge elastic
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,r2_score
linreg=LinearRegression()
linreg.fit(X_train_scaled,y_train)
y_pred=linreg.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error",mae)
print("R2 score",score)
plt.scatter(y_test,y_pred)
# Out:
# Mean absolute error 0.6061279917871262
# R2 score 0.9830411960394778

# %% [markdown]
# ## Lasso Regression

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error,r2_score
lasso=Lasso()
lasso.fit(X_train_scaled,y_train)
y_pred=lasso.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error",mae)
print("R2 score",score)
plt.scatter(y_test,y_pred)
# Out:
# Mean absolute error 1.1203368882393199
# R2 score 0.9511364350928344

# %% [markdown]
# #if r2 score is decressed it does not mean that model is bad may be it imporves overfitting that was earlier

# %% [markdown]
# ## ridge regression:

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error,r2_score
ridge=Ridge()
ridge.fit(X_train_scaled,y_train)
y_pred=ridge.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error",mae)
print("R2 score",score)
plt.scatter(y_test,y_pred)
# Out:
# Mean absolute error 0.624285369732625
# R2 score 0.9823948045469816

# %% [markdown]
# ## Elastic Netregression

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error,r2_score
elasticiii=ElasticNet()
elasticiii.fit(X_train_scaled,y_train)
y_pred=elasticiii.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error",mae)
print("R2 score",score)
plt.scatter(y_test,y_pred)
# Out:
# Mean absolute error 1.914589409083375
# R2 score 0.8727957561729347

# %% [markdown]
# ## HyperParamter Tuning

# %%
from sklearn.linear_model import LassoCV
from sklearn.metrics import mean_absolute_error, r2_score
import matplotlib.pyplot as plt

# Model
lassocv = LassoCV(cv=5, random_state=42)

# Train
lassocv.fit(X_train_scaled, y_train)

# Best alpha
print("Best Alpha (Lasso):", lassocv.alpha_)

# Predictions
y_pred = lassocv.predict(X_test_scaled)

# Metrics
train_r2 = lassocv.score(X_train_scaled, y_train)
test_r2  = lassocv.score(X_test_scaled, y_test)

mae = mean_absolute_error(y_test, y_pred)
r2  = r2_score(y_test, y_pred)

print("Train R2:", train_r2)
print("Test R2:", test_r2)
print("MAE:", mae)
print("R2 Score:", r2)

# Plot
plt.scatter(y_test, y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("LassoCV Predictions")
plt.show()
# Out:
# Best Alpha (Lasso): 0.05761253346064308
# Train R2: 0.9674978565068263
# Test R2: 0.9814596091517372
# MAE: 0.6513223833762647
# R2 Score: 0.9814596091517372

# %%
lassocv.mse_path_
# Out:
# array([[50.65386968, 76.54197718, 42.60540011, 85.19903601, 37.22447771],
#        [44.75111814, 74.82132255, 38.341692  , 85.19903601, 33.05643554],
#        [39.36934038, 67.35349762, 32.91718118, 77.16947646, 28.98441557],
#        [34.66809152, 60.76849885, 28.30179163, 70.00628728, 25.07891899],
#        [30.56005987, 54.39656706, 24.38332378, 63.69553448, 21.70030699],
#        [26.96916466, 47.86216351, 21.06462063, 58.13161794, 18.77862509],
#        [23.82945553, 42.15575307, 18.26138649, 53.22232605, 16.25301222],
#        [21.08318369, 37.17090521, 15.90095328, 46.89293347, 14.07124316],
#        [18.68014904, 32.81473426, 13.92043855, 41.32635877, 12.18732916],
#        [16.57661964, 29.00744813, 12.26540003, 36.4658746 , 10.56155236],
#        [14.73438066, 25.67846082, 10.88893934, 32.22081976,  9.15943046],
#        [13.12047322, 22.76665973,  9.75047302, 28.5122238 ,  7.95103045],
#        [11.70583482, 20.21881242,  8.81511714, 25.27132199,  6.9102242 ],
#        [10.46524798, 17.98854548,  8.05270156, 22.43755884,  6.01478795],
#        [ 9.3767302 , 16.03510498,  7.43725597, 19.96021847,  5.24498166],
#        [ 8.42111585, 14.32403577,  6.94642496, 17.79310065,  4.58383524],
#        [ 7.58169241, 12.82425291,  6.56076348, 15.89663692,  4.01663006],
#        [ 6.84378852, 11.50901635,  6.26417786, 14.23635715,  3.53060271],
#        [ 6.19489185, 10.35501678,  6.04228232, 12.78222819,  3.11468778],
#        [ 5.62379959,  9.34193186,  5.88291763, 11.50807956,  2.75923473],
#        [ 5.12083007,  8.4520405 ,  5.77567262, 10.39110361,  2.45606851],
#        [ 4.6775323 ,  7.66988713,  5.71164494,  9.41101171,  2.19791083],
#        [ 4.28652763,  6.98198949,  5.68282488,  8.55134909,  1.97852702],
#        [ 3.94137191,  6.37637486,  5.68356125,  7.79653235,  1.79251976],
#        [ 3.63643564,  5.84322598,  5.70793084,  7.13338426,  1.63521811],
#        [ 3.3667288 ,  5.37333938,  5.75125449,  6.55041287,  1.50258134],
#        [ 3.12810133,  4.95889114,  5.80957204,  6.03759288,  1.39111535],
#        [ 2.91671292,  4.59304889,  5.87953968,  5.58617663,  1.29780014],
#        [ 2.7292744 ,  4.269844  ,  5.87953968,  5.18852959,  1.22006541],
#        [ 2.56290779,  3.98406084,  6.04352345,  4.83776003,  1.15558641],
#        [ 2.41509369,  3.73114033,  6.04352345,  4.52853764,  1.10245117],
#        [ 2.2836257 ,  3.50709599,  6.22536011,  4.25551426,  1.05898386],
#        [ 2.16657063,  3.30844077,  6.22536011,  4.01424839,  1.02374009],
#        [ 2.06223389,  3.13212334,  6.4141371 ,  3.80085995,  0.99547607],
#        [ 1.96912929,  2.975395  ,  6.4141371 ,  3.61195699,  0.97312165],
#        [ 1.88591176,  2.83608443,  6.60106217,  3.44457322,  0.95575694],
#        [ 1.81152305,  2.71205029,  6.60106217,  3.29611371,  0.94259196],
#        [ 1.7449114 ,  2.60149572,  6.78083729,  3.1643075 ,  0.93305331],
#        [ 1.6851924 ,  2.50284535,  6.78083729,  3.04716636,  0.92635079],
#        [ 1.63158848,  2.41471684,  6.94950477,  2.94288818,  0.92209123],
#        [ 1.58341525,  2.33589657,  6.94950477,  2.85008221,  0.91985177],
#        [ 1.54006992,  2.26531843,  7.10672743,  2.76733453,  0.91927054],
#        [ 1.50102114,  2.2020453 ,  7.10672743,  2.6934711 ,  0.92003946],
#        [ 1.46580022,  2.14525292,  7.25092458,  2.62746236,  0.92189678],
#        [ 1.43399338,  2.09146032,  7.25092458,  2.56840425,  0.92189678],
#        [ 1.40523503,  2.04155418,  7.38197339,  2.51550247,  0.92802312],
#        [ 1.40523503,  1.99831894,  7.38197339,  2.46805865,  0.92802312],
#        [ 1.33071057,  1.96088078,  7.48954289,  2.42545846,  0.92071999],
#        [ 1.29537531,  1.92847417,  7.48954289,  2.38718052,  0.92071999],
#        [ 1.29537531,  1.90043536,  7.54461128,  2.35271501,  0.89516219],
#        [ 1.23653093,  1.87618277,  7.54461128,  2.32165399,  0.89516219],
#        [ 1.23653093,  1.85521422,  7.59662139,  2.27463174,  0.87914176],
#        [ 1.19047897,  1.83709352,  7.59662139,  2.2166033 ,  0.87914176],
#        [ 1.19047897,  1.83709352,  7.67577551,  2.16443818,  0.8782827 ],
#        [ 1.1542908 ,  1.80792789,  7.67577551,  2.11747813,  0.8782827 ],
#        [ 1.1542908 ,  1.80792789,  7.79422144,  2.0751982 ,  0.8802504 ],
#        [ 1.12574021,  1.7862203 ,  7.79422144,  2.03700489,  0.8802504 ],
#        [ 1.12574021,  1.7862203 ,  7.90924338,  2.00249591,  0.88399916],
#        [ 1.10312029,  1.77013506,  7.90924338,  1.97134968,  0.88399916],
#        [ 1.10312029,  1.76369783,  8.02009346,  1.94459278,  0.88880073],
#        [ 1.06167987,  1.76369783,  8.02009346,  1.92179278,  0.88880073],
#        [ 1.06167987,  1.72764218,  8.12402145,  1.92179278,  0.86575039],
#        [ 1.01598218,  1.72764218,  8.12402145,  1.87498771,  0.84788058],
#        [ 1.01598218,  1.68314371,  8.22010144,  1.84235636,  0.8319254 ],
#        [ 0.97938018,  1.68314371,  8.22010144,  1.81317507,  0.81775493],
#        [ 0.97938018,  1.64656073,  8.30704281,  1.78712777,  0.80515663],
#        [ 0.94994309,  1.64656073,  8.30704281,  1.76384788,  0.79394415],
#        [ 0.94994309,  1.61633142,  8.38724974,  1.74317922,  0.79394415],
#        [ 0.92614133,  1.61633142,  8.38724974,  1.74317922,  0.77506304],
#        [ 0.92614133,  1.59131133,  8.38724974,  1.71042218,  0.77506304],
#        [ 0.90681075,  1.58043927,  8.52009291,  1.71042218,  0.76025806],
#        [ 0.89930043,  1.57044549,  8.52009291,  1.68413451,  0.75382109],
#        [ 0.89302863,  1.56155112,  8.59680302,  1.68413451,  0.74954711],
#        [ 0.88744284,  1.55407391,  8.59680302,  1.66291735,  0.74563354],
#        [ 0.88244517,  1.54748387,  8.59680302,  1.66291735,  0.74220461],
#        [ 0.87859829,  1.54149959,  8.69452974,  1.64583453,  0.73915075],
#        [ 0.87509552,  1.53605685,  8.69452974,  1.6382947 ,  0.73642381],
#        [ 0.87199805,  1.53110093,  8.69452974,  1.63170036,  0.73398564],
#        [ 0.86925621,  1.52658337,  8.77459556,  1.62548725,  0.73180308],
#        [ 0.8668263 ,  1.52246105,  8.77459556,  1.61991158,  0.729847  ],
#        [ 0.86473265,  1.51879453,  8.77459556,  1.61549076,  0.7280918 ],
#        [ 0.86281042,  1.51533226,  8.8423656 ,  1.61275874,  0.72651494],
#        [ 0.86110357,  1.51277369,  8.8423656 ,  1.61021429,  0.72532785],
#        [ 0.85958563,  1.51061879,  8.88175532,  1.60833268,  0.72403645],
#        [ 0.85823338,  1.50850946,  8.88175532,  1.60647941,  0.72286843],
#        [ 0.85702736,  1.50658483,  8.91448586,  1.60484643,  0.72181421],
#        [ 0.85595056,  1.50527732,  8.91448586,  1.60345261,  0.72086108],
#        [ 0.85498802,  1.50446767,  8.94313789,  1.60226636,  0.71999828],
#        [ 0.8541817 ,  1.50378527,  8.94313789,  1.60155902,  0.71921633],
#        [ 0.85340715,  1.50318937,  8.96727111,  1.60076875,  0.71850682],
#        [ 0.8527135 ,  1.50266776,  8.96727111,  1.60002879,  0.71786231],
#        [ 0.85243719,  1.50222439,  8.98976776,  1.59939336,  0.71747941],
#        [ 0.85227602,  1.50180855,  8.98976776,  1.59915097,  0.71694586],
#        [ 0.85216052,  1.50145526,  9.00944432,  1.59850421,  0.7164445 ],
#        [ 0.85207885,  1.50114699,  9.00944432,  1.59830374,  0.7159873 ],
#        [ 0.85202595,  1.50087664,  9.0253709 ,  1.59806436,  0.71556971],
#        [ 0.85199431,  1.50063935,  9.0253709 ,  1.59780516,  0.71518777],
#        [ 0.85197785,  1.50043095,  9.04059825,  1.59756777,  0.71483809],
#        [ 0.85198179,  1.50015254,  9.04059825,  1.59736683,  0.71451765],
#        [ 0.85200114,  1.49964749,  9.05248841,  1.59720093,  0.71440852]])

# %% [markdown]
# ## SIMILARLY Hyperparamter tuning
#  FOR Ridge

# %%
from sklearn.linear_model import RidgeCV
from sklearn.metrics import mean_absolute_error, r2_score

# Define alphas
alphas = [0.01, 0.1, 1, 10, 50, 100]

# RidgeCV
ridge_cv = RidgeCV(alphas=alphas, cv=5)

# Train
ridge_cv.fit(X_train_scaled, y_train)

# Best alpha
print("Best Alpha (Ridge):", ridge_cv.alpha_)

# Prediction
y_pred = ridge_cv.predict(X_test_scaled)

# Metrics
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("MAE:", mae)
print("R2 Score:", r2)

plt.scatter(y_test, y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Ridge Regression (Tuned)")
plt.show()
# Out:
# Best Alpha (Ridge): 10.0
# MAE: 0.8122246356917506
# R2 Score: 0.9739166100558089

# %% [markdown]
# ## Saving Model

# %%
import pickle

pickle.dump(lassocv, open("models/reg_model.pkl", "wb"))

# %% [markdown]
# ## Scalar-🔹 scaler.pkl
#
# 👉 Ensures same preprocessing as training

# %%
import pickle

pickle.dump(scaler, open("models/scaler.pkl", "wb"))

# %%
features = ['Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'ISI','Region']
pickle.dump(features, open("models/features.pkl", "wb"))
